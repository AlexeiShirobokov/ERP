# %%
import pandas as pd

class Upload():
    def open(self, path):
        self.path = path
        return self

    def transform(self):
        df = pd.read_excel(self.path, sheet_name='Свод', header=1)
        self.df = df
        return print(df)

debitor=Upload() #создал объект
path='/Users/alexei/Yandex.Disk.localized/Analisys/Excel/3. Прочие задачи/Динамика проблемной дебиторки 31.01.2026.xlsb'
debitor.open(path)
debitor.transform()






# Create your models here.
#
# class Debitor(models.Model):
#     title = models.CharField(max_length=100)
#     content = models.TextField()
#     def __str__(self):
#         return self.title
# Out:
#            Unnamed: 0        2024          2025         2026    Общий итог
# 0                 NaN         NaN           NaN          NaN           NaN
# 1                 NaN         NaN           NaN          NaN           NaN
# 2      Названия строк         NaN           NaN          NaN           NaN
# 3     Авиа-Бизнес ООО         NaN  1.030000e+04          NaN  1.030000e+04
# 4            Адон ООО         NaN  2.060000e+06         0.00  2.060000e+06
# ..                ...         ...           ...          ...           ...
# 88      Шуман Н.С. ИП         NaN  1.379000e+05          NaN  1.379000e+05
# 89       Шумилов О.А.         NaN  3.472000e+05     86800.00  4.340000e+05
# 90  Эксперттехник ООО         NaN  2.981500e+05          NaN  2.981500e+05
# 91         Яндекс ООО     88230.0  6.219250e+05     93687.00  8.038420e+05
# 92         Общий итог  44089554.0  2.143289e+08  11646799.46  2.700652e+08
#
# [93 rows x 5 columns]
